# %%
# rap 모델
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop, Adam
from keras.utils.data_utils import get_file
import numpy as np
import pandas as pd
import random
import sys
import io
import re
# Out:
# Using TensorFlow backend.

# %%
lyric = pd.read_csv('./sample_data/music_lyrics_total.csv', encoding = 'utf-8')
child = pd.read_csv('./sample_data/music_lyrics_children_total.csv', encoding = 'utf-8')

# %%
child = child['lyrics'].drop_duplicates()
child.shape
# Out:
# (4209,)

# %%
text = ''

for i in range(2000):
    if child[i] != None:
        song = child[i]
#         print(song)
        song = re.sub('[\(\)-]', ' ', song)
        cleaned = song.lower().replace(' ', '\n')
    #     print(cleaned)
        text = text + " ".join(re.findall(r"[가-힣]+", cleaned)) + ' '
len(text)
# Out:
# 315139

# %%
text2 = ''
for i in range(6000):
    if lyric['lyrics'][i] != None:
        song = lyric['lyrics'][i]
#         print(song)
        song = re.sub('[\(\)-]', ' ', song)
        cleaned = song.lower().replace(' ', '\n')
    #     print(cleaned)
        text2 = text2 + " ".join(re.findall(r"[가-힣]+", cleaned)) + ' '
len(text2)
# Out:
# 2530914

# %%
text = text + text2
len(text)
# Out:
# 2846053

# %%
tokens = re.findall(r"[a-zA-Z가-힣'\s]", text)

chars = sorted(list(set(tokens)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 1744

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 955062

# %%
maxlen = 20
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 948678

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
# model.add(Dropout(0.5)) # 추가
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(lr=0.01))
model.summary()
# Out:
# Build model...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               958976
# _________________________________________________________________
# dense_1 (Dense)              (None, 1744)              224976
# _________________________________________________________________
# activation_1 (Activation)    (None, 1744)              0
# =================================================================
# Total params: 1,183,952
# Trainable params: 1,183,952
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

def on_epoch_end(epoch, logs):
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.3, 0.5]: # 0.2, 0.5
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

history = model.fit(
    x, 
    y,
    batch_size=512,
    epochs=10,
    callbacks=[print_callback]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/10
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 948678/948678 [==============================] - 433s 456us/step - loss: 3.3709
# ----- Generating text after Epoch: 0
# ----- diversity: 0.3
# ----- Generating with seed: "천생연분 배달의 민족과 심야식당남이사"
# 천생연분 배달의 민족과 심야식당남이사랑 나는 모두 다 함께 하고 싶어 그대 나의 마음을 기다려 내게 다시 돌아가네 내 맘을 내게 해 내 맘을 보여 우리 둘이 걷는 우리 둘만의 남자 나는 모두 다 같이 날 잡아 어디든 가 그래 나 봐 너와 함께 있어 나 그 때 그 사람 이제 내 맘 속에 나 나 나 나 나나 나나 나나 나나 나나나 나나 나나나 나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나 나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나나
# ----- diversity: 0.5
# ----- Generating with seed: "천생연분 배달의 민족과 심야식당남이사"
# 천생연분 배달의 민족과 심야식당남이사랑 보고 싶어 오늘 밤 나의 모습이 어디로 가 이제 이 순간 아직 너를 만나고 내 맘을 기다리는 너의 모두 다 또 불어오는 나의 맘을 만나게 미래 전부 다 시간을 보고 싶어 나 어디로 가야 해 내 옆에 있어 내가 있어 이제 내 맘을 너를 만난 게 네가 많은 걸 그렇게 있어 널 만나 봐 너무 미안해 오늘 밤 그 인사를 나를 않는 건 너의 맘 아니었어 내 맘이 이 맘 안 되는 예쁜 너의 목소리 가득한 시간이 되어 이 시간이 날 찾아보지 않아 오늘 밤에 지금 그 손을 잡고 나를 불러봐 그 때 너의 눈을 떠 버려 봐 나는 너를 안아줄 수 없어 너의 바다 보이고 있어 내 맘을 알아 난 가끔 나를 만약 많은 것 같아 술 안 돼 그런 너 없는 건 이제 내게 너와 함께 날 때 너의 모든 것 같아 나 지금 시간 속에 어디까
# Epoch 2/10
# 948678/948678 [==============================] - 442s 466us/step - loss: 3.0090
# ----- Generating text after Epoch: 1
# ----- diversity: 0.3
# ----- Generating with seed: "내 인생 그댈 좀 더 알고 싶어 난 "
# 내 인생 그댈 좀 더 알고 싶어 난 지금 이 순간 그 속으로 가득한 나의 손을 잡고 있어 내 맘이 모르는 걸까 날 바라보면 내 맘은 다 내려 해 줘 너를 보면 내 맘을 알아 가 지금 이 순간 그 말이 너무 좋아 너의 사랑이 지나 보고 싶어 내 맘 알아 이젠 그냥 내 맘 속에 가만히 있어 그대로 다 잊어버린 나의 내 맘을 다 잊고 있어 그래 내 맘 알아 가 이 시간이 지나 너와 함께 하는 너의 그 말들을 내 맘을 알아 다 가득 안 하고 싶어 그냥 아니면 아직도 그래도 내 맘 알아 내 맘이 들려 가 버린 걸 아닌 척 하네 너의 그 말이 아니면 너 없이 그냥 가 이제 그 말이야 그대 모습을 더 이상 이 순간이 그대로 너를 보고 싶어 그대 곁에 있어줘 그대로 있어요 그대로 내가 그대로 있어줘 이 순간이 너를 찾아 내 맘 속에 네가 있어 그대 모든 게
# ----- diversity: 0.5
# ----- Generating with seed: "내 인생 그댈 좀 더 알고 싶어 난 "
# 내 인생 그댈 좀 더 알고 싶어 난 네 이름은 갈 수 없는 걸 그냥 가만히 있는 날이 좋아 나의 행복한 곳이 아니고 싶어 아무것도 모르겠지만 그리워 다음 말을 하는 것 같아 그게 많이 그대로 어디도 가는 걸 알아서 이 순간이 아는 것 같아 우리 둘이 가득히 나는 어떻게 좋아하는 것들이 다 알아 이 말고 이제 내 모습 안 아니 나 어때 난 너의 손 잡고 작은 사이 우릴 알아 미안해 너와 함께 있어요 그대 모든 것들이 날 다시 돌아보고 있을 때 어제 가만히 남아있어 우리 둘이 가득히 나의 손 잡아 내 맘에 난 가도 또 다 잊었지만 그냥 다시 돌아갈 수 없는 내 맘 너와 함께 하는 마음 다시 돌아가는 너의 향기가 다시 돌아가 지금 내 맘 알아 네 맘을 내 맘 속에 내 맘을 들어 내 맘 속에 있어 내 모든 것이 지워버린 걸 지금 이 순간이 안 행복하
# Epoch 3/10
# 948678/948678 [==============================] - 431s 454us/step - loss: 2.9218
# ----- Generating text after Epoch: 2
# ----- diversity: 0.3
# ----- Generating with seed: " 나도 부자야하하하하 우리는 착한 어"
#  나도 부자야하하하하 우리는 착한 어디로 가는 길이 다 너무 좋아 너무 좋아 너무 좋아 그대 내가 좋아 좋아 우리 모두 다같이 나는 나는 이 밤 이 밤에 내 마음 속에 내게 다가와 줘 너의 곁에 있어줘 그대 사랑을 사랑해 사랑을 하는 너의 말이 좋아 너무 좋아 아무것도 없이 나를 좋아하는 말 하지 않아도 난 그래 너 하나 둘 하나 둘 둘 둘 둘 하나 둘 둘 둘  세 어머 물고 나는 나는 이 순간 다 다 같이 있어 내 마음 이 새벽 그 사람들 속에 너의 눈을 감아 그대 없이 그대 모든 걸 다 알아 그때 그대 모습이 우리는 그대 사랑이 나는 너의 말이 아니라고 말해주길 바래 나는 나는 이 순간 이 순간 이 순간 다 내 맘 너무 아름다운 걸 알아 너의 눈을 감아 내 맘 속 내 손을 잡아줘 너의 곁에 있어줘 너를 사랑해 너의 말이 아냐 너의 마음이
# ----- diversity: 0.5
# ----- Generating with seed: " 나도 부자야하하하하 우리는 착한 어"
#  나도 부자야하하하하 우리는 착한 어디에 도 정말 그저 멀어지는 그 길이 너무 좋아 좋은 것도 아니라고 하지 마 내 손잡고 싶어 그래 그냥 다 보이는 내 머릿속에 너의 말이 좋아 너의 사랑 하나 둘 시간은 없다고 또 말려 내 생각이 되어 내가 지워 내 손을 잡아줘 너의 숨결에 남아 있는 나와 함께 있는 나의 모든 것처럼 너의 눈빛에 널 사랑해 우린 난 널 만나고 있어 내 맘은 아니 아니 나 아니라고 아니 아무것도 못 하는지 이런 내 마음을 다시 만나 대답하지 않아도 너만 보이게 날 나를 놓지 않아 너의 사랑을 가득 한 날 눈을 감아도 나를 보며 내가 지워주는 걸 알아 난 이런 내 마음을 그냥 아프게 해도 해 내가 말해 넌 이 순간을 다 알아가 나는 말야 아 마음을 다시 돌아갈 거야 그대 모든 걸 내 옆에 있는 걸 너 없이 나를 믿어줘 그대 그
# Epoch 4/10
# 948678/948678 [==============================] - 432s 455us/step - loss: 2.8678
# ----- Generating text after Epoch: 3
# ----- diversity: 0.3
# ----- Generating with seed: " 때에 따라아무렴 어때까무러치게더불어"
#  때에 따라아무렴 어때까무러치게더불어가 우린 매일 매일 밤 이 밤을 지나고 싶어 어디든 가는 것처럼 너를 향해 내 맘에 들어가 그대 떠나 봐 너를 기다려 나를 떠올려요 그대 곁에 있어요 그대 곁에 있어요 그대여 나를 좋아하는 건 이 순간에 너에게 말해줘 그래 그래 그냥 아름다운 사람들이 아니면 너를 데려가 봐요 내 맘 속에 내 맘 속에 들어가 가는 건 너를 위해 너를 위해 눈을 감아 네 맘을 내 맘 속에 남아 있는 것만 같아 그래 그래 난 그래 그래 난 너무 좋아 사랑해 이젠 안돼 나는 그 말이 좋아 내 맘이 아니라고 말해 나는 지금 이 순간에 그대를 보내지만 그래 그래 난 네가 좋아 그 말이 좋아 그래 그래 그래 내 맘이 아니 아니라고 말해 너는 나를 사랑해 이젠 내게 말해줘 내게 말하지 않았어 그래 난 이 순간 널 사랑한 일이 없이 이제
# ----- diversity: 0.5
# ----- Generating with seed: " 때에 따라아무렴 어때까무러치게더불어"
#  때에 따라아무렴 어때까무러치게더불어 이 밤에 내 맘을 들고 있는 걸까요 날 위해 보내줄 떠다르면 그대 마음이 아니야 그게 그냥 보이는 그대 모든 게 내게 반짝이는 그 말도 할 수 없는 지금 내 맘이 너에게 말해줘 알아 내 맘에 남겨진 나의 하루가 널 보내고 있어 눈물이 나 이 순간이 되었어요 나를 보고 싶은 것들이 다 몰래 대답없는 나쁜 이 맘 아름다운 건지 말고 나를 떠나 난 괜찮아 그리워 하루 종일 좋아 내 맘 너의 곁에 있는 건지 그 순간  너를 위해 살아가는 건 아무 말도 없이 아냐 그냥 바라지 않아 이제 네게 말해 너무 많이 사랑해 날 위해 다 시 눈을 감았죠 난 이 길이 가는 곳으로 걸어 아무 생각이 이젠 없어 내 맘 매일 더 보내는 것처럼 너무 힘든 이 시간 이 순간에 너를 따라와 사랑해 널 위해 보이는 것도 없어 그런 이유를
# Epoch 5/10
# 948678/948678 [==============================] - 418s 441us/step - loss: 2.8323
# ----- Generating text after Epoch: 4
# ----- diversity: 0.3
# ----- Generating with seed: " 네가 내 옆에 있어 주기를말하지 않"
#  네가 내 옆에 있어 주기를말하지 않아도 돼 이제 그때 그 말이 아냐 너무 많은 것을 그래 난 아직 내가 사랑해 너를 보고 싶어 난 나를 보고 싶은데 난 너를 만나 그 시간 속에 너를 보고 있어 너와 나의 사랑을 그리워 그대 그대 곁에 있어줘 너를 가득 채워줘 난 너에게 말해줘 너를 알게 되는 그 말 그대로 있어줘 그대로 있어줘 그때 그 시간 그 사람 이 밤은 없어 이 밤을 지나고 있어 내 맘을 모르게 네 맘을 내게 보여줘요 그대 곁에 있을 때 날 떠나 봐도 돼 그대 없는 너의 말투 내 마음이 더 많은 건 아무것도 없이 나 한 번 더 더 더 많은 걸 보고 싶은데 난 그냥 너에게 말해 너의 맘을 알아 너를 사랑해 그 말 그 말 그 안에 나를 그리고 있어 난 그래도 돼 너의 눈빛을 보내는 것 같아 그 시간 지나가 나를 찾아 오지 않아 그저 내 맘
# ----- diversity: 0.5
# ----- Generating with seed: " 네가 내 옆에 있어 주기를말하지 않"
#  네가 내 옆에 있어 주기를말하지 않아나 같은 마음을 바라보라면 나를 내가 손 잡아줘요 그대 곁에 있으면 좋을 때 말 또 내게 있어 왜 두려워 가 게 말야 그때 난 너 어떤 말이 나를 사랑하는 걸 알 수 없어 꼭 내가 하던 그 말 한 마음 이 밤을 지나면 그대로 있어 내가 내가 고마워 주고 싶어 너무 좋아 내게 바라보는 그 순간 이 밤 그 사람 그대로 있어줘 나 어디로 가는지 어디에 있을까 내 맘을 들어 줘 그대 나의 곁에 있을게 너에게 말해줘 지금 이 순간 이렇게 너에게 말해줘 나의 맘속의 동안 바라서 그 날 떠나가고 싶어 그대 곁에 있어줘요 그대 떠나 손을 잡고 있는 것 같아 이제 내가 바라봐 내가 아무것도 없이 나 그 시간이 나를 봐 우리의 모든 것들을 바라보는 나의 마음을 어디로 가야 할 것 같아 사랑을 말할게요그때 그 안에 내게 말해
# Epoch 6/10
# 948678/948678 [==============================] - 420s 443us/step - loss: 2.8077
# ----- Generating text after Epoch: 5
# ----- diversity: 0.3
# ----- Generating with seed: "넣는 것 같아손을 뻗으면 닿을 수 있"
# 넣는 것 같아손을 뻗으면 닿을 수 있을까 나는 어느 날 그 때 너의 눈앞에 있는 그 순간 속에 서로 사랑하는 사람 그대로 그대를 만나게 되는 말들 아닌데 아니 너와 나 그 누구도 나를 나는 너 없는 걸 알고 있는 걸 알아 어쩌면 너무 좋아 그래 그래 우리 다시 만나 이제 그 말은 하지마 그냥 다 가져가 내 맘을 몰라 너를 만나게 해 너의 맘을 알아 줄래 그래 다 알아 그래 난 이런 내 맘을 다시 돌아올 수 있을까 우리 사랑했던 그 순간 속에 그 사랑 이 순간 너의 맘을 알아줘 내 맘을 들어줘 그 순간 그대와 함께 걸어갈 수 있을까 그래 그래 내가 좋아 나는 너무 좋아 내 맘 아프게 해 너의 얼굴 눈물 나에게 가득 채워줄래 난 너의 맘이 어제 그 모든 게 다 가득 채워 내 맘을 들어 내 손을 잡고 있어 너의 눈빛 속에 나를 아프게 하네 내 맘을
# ----- diversity: 0.5
# ----- Generating with seed: "넣는 것 같아손을 뻗으면 닿을 수 있"
# 넣는 것 같아손을 뻗으면 닿을 수 있을까 내가 더 멀어져가 너를 사랑하게 하고 싶은 이 순간 이 순간이 나를 보고 싶어 너와 함께 해요 나를 찾아올 때 내가 다가와 다시 오면 우린 이제 남았어 우리 사랑이 나를 찾아 속삭여줘 나를 생각하면 나를 가지마 너를 내 맘을 손가락 하는 것 같아 너와 나 이렇게 내 사랑이 아닌데너 때문에 내가 더 운명이라도 해 그래 난 너에게 나를 아프게 해 그 때 나를 떠나지 못한 내 맘 속에 너와 나 그래 그래 네가 아니지만 이제 나와 함께 있는 것 같아 그 시간이 가득한 밤이 되어 내게 다가와 주고 싶어 이젠 무슨 말을 하지만 그래 그래 난 이런 말 말해줘 내 맘을 들어줘 그대 맘에 있는 이 순간 너와 나 그 생각이 나를 보고 싶어 나를 떠나가 봐 이 길이 기다려 내 맘에 눈을 감으면 이 밤이 지나가는 듯이 또
# Epoch 7/10
# 948678/948678 [==============================] - 412s 434us/step - loss: 2.7885
# ----- Generating text after Epoch: 6
# ----- diversity: 0.3
# ----- Generating with seed: "아 우린 돈 걱정 안 해 어느 클럽이"
# 아 우린 돈 걱정 안 해 어느 클럽이지 않는 걸 알아 너와 나 그 때 내 마음을 보면 너의 맘을 보면 그 순간에 있어 너의 눈빛이 보여줘 너의 눈빛이 너무 멀리 가득 채워줘 너의 모든 걸 다 가져가 너의 모든 게 다 가져가 누군가 보고 싶어 너와 나 너와 함께 하는 그 순간이 다 가득 채워줘 너의 모습을 보면 그대 모습으로 가득 채워 너와 나의 사랑 그대의 그 말 하나 둘 바래 나의 모든 걸 다 사라지는 밤 그대 그 모든 게 다 다 같이 가요 우리 둘이 만나 내 맘을 보면 그냥 그냥 다가가 다가와 있어 난 아무 말도 없이 내 손을 잡고 있어 그냥 지금 이 순간이 나를 바라봐 그냥 나의 마음을 보고 싶어 나는 그냥 너무 위험해 나 나 나 나 나 나 나 나 나 아니면 아무 말도 없이 너무 많이 그냥 너를 보면 너의 기분 이제 나의 마음을 보면 우
# ----- diversity: 0.5
# ----- Generating with seed: "아 우린 돈 걱정 안 해 어느 클럽이"
# 아 우린 돈 걱정 안 해 어느 클럽이지 마 넌 내 가슴이 무너져 다가와 그리워 그대 모든 순간에 너도 그대와 함께 할 수 있을까 나는 너의 곁에 있을 수 있을까 아무 말도 없이 오늘 밤에 나 그 밤을 지나면 내 맘은 보이지 않아 나도 모르게 그때 그 때 내게 와줘 내 작은 별들도 있어 이 밤 너와의 시간 속에 너를 보면 너에게 어디든 너를 위해 두려워 잊을 수 있게 그댈 지금 밤을 지나가 그때에 나를 찾아 이 순간 가려진 사랑을 믿고 있어 너도 나와 함께 하는걸 다 가장 너의 모습을 보고 있어 내 마음을 보면 난 너의 마음을 잃은 마음이 지나도 너의 마음을 보고 싶어 그때의 하루는 내 모습을 보내어 너를 보내고 있어 너의 맘은 날 바라보면 나를 위해 내가 원하는 마음을 다 내 곁에 있어 내 손을 잡아 나의 마음 다시 새겨진 나의 시간들이 아냐
# Epoch 8/10
# 948678/948678 [==============================] - 414s 436us/step - loss: 2.7753
# ----- Generating text after Epoch: 7
# ----- diversity: 0.3
# ----- Generating with seed: "히 다 뒤집어엎을 자만심 아닌 자신감"
# 히 다 뒤집어엎을 자만심 아닌 자신감 그 시간들이 너무 힘들었다면 그대 모습이 있어 너와 나의 이 길을 걸어가는 것들은 다 그대로 가는 대로 이렇게 어디로 가는지 몰라 난 너와 나 지나간 너의 말을 하는 그 시간 속에 너와 함께 있어 우리 함께 있으면 우리 사랑할 수 있어 너의 모든 것들이 가는 곳으로 가까이 가는 길을 걸어 내게 있어 너의 사랑이 좋아 그대로 있어 주는 그대로 있다면 우리 이 순간 다 사라져 가는 그 순간이 지나가는 그 시간 속에 너를 바라볼 수 있을까 너를 안아줄 수 있는 걸 알았어 그대 모습이 있어 그대가 있어 너의 곁에 있어줘 그대가 내게 사랑해 주고 싶어 이젠 다 너무 사랑했었다면 너를 안아줄게 그대로 돌아와 줘 너를 보면 내 맘을 다 다 가져가 너를 보면 내 맘을 알아줘 너를 안아줄 수 있어 너 없이 너를 보면 너만
# ----- diversity: 0.5
# ----- Generating with seed: "히 다 뒤집어엎을 자만심 아닌 자신감"
# 히 다 뒤집어엎을 자만심 아닌 자신감 마음을 다 알고 있지만 우리 가자 갈 때가 내 맘 모르겠다 그걸 나와 같이 걷는 날아가 아닌 척 해도 네가 없는 시간이 나를 쳐다보는 너와 나 함께 있어 기다리던 내 모습이 가까이 있어 여기 있어 그대로 있다면 그 사람 선생님 한번  더 새로 다 내 번호 이대로 가신 대로 전화해 내 이름을 다 그냥 너의 손을 잡아주지 않아 그래 이 길을 가 너와 함께 있어 너와 나 하나 둘 셋 기다 다 말해요 이대로 걷다가 너무 가까이 가는 날 피어와 이 길을 가네 그대 손을 잡아볼까 너를 보고 있어 이젠 그대여 나무 소식을 한다면 내 모든 게 내 곁에 있나요 그대 곁에서 있어요 이 사랑이 말할 수 있게 감정들 이젠 그냥 어디로 가는지 알고 있었다면 난 너를 안아주는 말이 이렇게 그리워하는 너의 시간들이 다 알아 버렸어
# Epoch 9/10
# 948678/948678 [==============================] - 413s 436us/step - loss: 2.7648
# ----- Generating text after Epoch: 8
# ----- diversity: 0.3
# ----- Generating with seed: "그 거리를나를 꿈꾸게 했던 그들이 있"
# 그 거리를나를 꿈꾸게 했던 그들이 있어 그대로 내 곁에 있어줘 그대로 있어줘 그대로 있어줘 그대로 있어줘 너를 보면 그대 모습이 날 수 있는 것 같아 이젠 다 다 알 수 있어 너의 눈빛이 나는 날 보는 그 말이 아니라고 말해줘 그대로 있어줘 너를 향해 있어 이 순간 내 맘을 들어줘 너를 보면 그대로 있어줘 그대로 있어줘 그대가 좋아요 그대 곁에 있어줘요 그대 없이 나를 보면 그대 아름다워 그대 모습이 날 비추는 그 순간 속에 나를 더 하루 종일 너를 보면 그냥 말해줘 그대 눈빛이 나를 비추게 해가 뜨거워져 가는 그 모습이 아닌 것 같아 너를 기다리고 있어 너의 사랑이 되고 싶어 내가 더 이상 그대로 있어줘 너를 사랑해 이해해줘 너를 향해 있어 우리 함께 걸어가 너를 보면 그냥 너를 사랑해 이 노래가 나를 사랑해줘 그대 모습이 되어 주길 바래
# ----- diversity: 0.5
# ----- Generating with seed: "그 거리를나를 꿈꾸게 했던 그들이 있"
# 그 거리를나를 꿈꾸게 했던 그들이 있어 내가 알아 주던 그 순간 이 순간은 이제 그만 그대의 기억 속에 너를 사랑해 사랑해 그대는 모르는 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사람 사랑 사랑 사랑 사랑을 사랑 사랑 사랑 이 사랑 사랑 사랑 사랑 사랑 사랑을 들여사는 사람 모두 다 너를 놓치기 전에 너를 더 잘 알잖아 너와 함께 하는 내가 있어 네가 없는 모습은 날 위해 너를 향해 있어 나를 감싸 안에 안겨 나는 너를 사랑해줘 그 순간 속에 가득 채워 아파뭐가 내 눈물이 나는 너와 나 난 너무 아름다워서 난 미안해 너의 하루가 너무 많이 다시 세상을 지나 내 다른 곳에 가라 까만 하늘 위에 가 있는 사랑 말아 너의 얼굴 우리 둘이 오늘도 내 마음을 가요 그대여 눈물이 나고 싶어 오늘은 어디로 가야할 때 더 있어 건너가 보여 넌 이상해 너는 나를
# Epoch 10/10
# 948678/948678 [==============================] - 419s 442us/step - loss: 2.7562
# ----- Generating text after Epoch: 9
# ----- diversity: 0.3
# ----- Generating with seed: "또다시 돌아오기까지가왜 이리 힘들었을"
# 또다시 돌아오기까지가왜 이리 힘들었을까 너의 맘을 다 그리워 하지 않아도 돼 나의 사랑이 되고 싶어 그대 날 기억해 기억해줘 그대 곁에 있을게 너무 좋아 그렇게 생각하는 너의 맘이 내 맘을 다 알아 너만 보면 너의 마음을 다 못 했어 이 마음을 다 사랑하지 않아도 돼 너무 그 말이 너무 좋아 말하지 말아 줘 난 너의 맘을 알아줘 그대 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑 사랑해요 그대 곁에 있어요 그대 곁에 있어줘요 그대 내 맘속에 있는 곳을 찾아 가는 길 너와 나의 마음을 주고 싶어 난 너무 좋아 내 맘 다 다 많이 좋아 하나 없이 나 어디로 가야 하는 건 말야 이 바로 너무 좋아 우리 한 일 생각이 나 나 혼자 남아서 너를 위해 너의 너의 마음을 꿈꾸고 있어 우리 함께 하는 너의
# ----- diversity: 0.5
# ----- Generating with seed: "또다시 돌아오기까지가왜 이리 힘들었을"
# 또다시 돌아오기까지가왜 이리 힘들었을 때만 더 아니 그 말 다 그리고 있으니까 한 걸음 물들여 오는 사람 한 걸음 또 두려워 하지 않아 너무 좋아 좋아 그냥 우리 사인데 이제 내 맘을 알아준 이 길에 사랑했어 너와 같이 걷던 그때가 그렇게 잊혀질 거야 우리 함께 했던 그 모든 걸 알 수 있다고 말해줘 난 잠든 생각이 들어 너무 좋아 그래도 너무 많은 사람들은 다 이제 그냥 우리 만나지 않아도 그 말 그래 너만 보고 싶어 그 때문에 너를 기다려줘 저기 저 기억 내 맘을 다 잊고 있으면 좋겠어 난 너무 많이 좋아 어떻게 해사랑하고 싶어 그러니까 그대 곁에 있어줘 나 혼자만 가는지 널 믿고 있어 그 말이 말 하고 있겠지만 이젠 내 맘 가득 담아 너만 보고 싶다고 말하고 싶어 같이 있어 너의 전부 내가 있을 때면 어려워 우리 함께 있을 때 비워 끝에

# %%
from keras.models import load_model

model.save('./sample_data/model_child2000_lyric6000_v1.h5')
